# %%
#Leitura da base de dados
import pandas as pd

df = pd.read_csv('/Workspace/Users/glauber.bomtempo@samarco.com/7DaysOfCode/dataset.csv')  
df.head()
# Out:
#    Unnamed: 0                track_id  ... time_signature track_genre
# 0           0  5SuOikwiRyPMVoIQDJUgSV  ...              4    acoustic
# 1           1  4qPNDBW1i3p13qLCt0Ki3A  ...              4    acoustic
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  ...              4    acoustic
# 3           3  6lfxq3CG4xtTiEg7opyCyx  ...              3    acoustic
# 4           4  5vjLSffimiIP26QG5WcN2K  ...              4    acoustic
#
# [5 rows x 21 columns]

# %%
#ver informações gerias do dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 17.5+ MB

# %%
#excluir linhas com valores nulos
df = df.dropna(subset=['artists', 'album_name', 'track_name'])

# %%
#ver informações gerias do dataframe após as exclusões
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113999 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        113999 non-null  int64
#  1   track_id          113999 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        113999 non-null  int64
#  6   duration_ms       113999 non-null  int64
#  7   explicit          113999 non-null  bool
#  8   danceability      113999 non-null  float64
#  9   energy            113999 non-null  float64
#  10  key               113999 non-null  int64
#  11  loudness          113999 non-null  float64
#  12  mode              113999 non-null  int64
#  13  speechiness       113999 non-null  float64
#  14  acousticness      113999 non-null  float64
#  15  instrumentalness  113999 non-null  float64
#  16  liveness          113999 non-null  float64
#  17  valence           113999 non-null  float64
#  18  tempo             113999 non-null  float64
#  19  time_signature    113999 non-null  int64
#  20  track_genre       113999 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 18.4+ MB

# %%
#excluir colunas desnecessárias
if 'Unnamed: 0' in df.columns:    df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#                  track_id                 artists  ... time_signature track_genre
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino  ...              4    acoustic
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward  ...              4    acoustic
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN  ...              4    acoustic
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis  ...              3    acoustic
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet  ...              4    acoustic
#
# [5 rows x 20 columns]

# %%
#verificando os valores nulos por coluna
df.isnull().sum().sort_values(ascending=False)
# Out:
# track_id            0
# artists             0
# time_signature      0
# tempo               0
# valence             0
# liveness            0
# instrumentalness    0
# acousticness        0
# speechiness         0
# mode                0
# loudness            0
# key                 0
# energy              0
# danceability        0
# explicit            0
# duration_ms         0
# popularity          0
# track_name          0
# album_name          0
# track_genre         0
# dtype: int64

# %%
#verificando se há linhas duplicadas
df.duplicated().sum()
# Out:
# 450

# %%
#removendo duplicados
df = df.drop_duplicates()
df.duplicated().sum()  # deve retornar 0
# Out:
# 0

# %%
#estatísticas descritivas
df.describe().T
# Out:
#                      count           mean  ...          75%          max
# popularity        113549.0      33.324433  ...      50.0000      100.000
# duration_ms       113549.0  228081.370844  ...  261588.0000  5237295.000
# danceability      113549.0       0.567031  ...       0.6950        0.985
# energy            113549.0       0.642091  ...       0.8540        1.000
# key               113549.0       5.309452  ...       8.0000       11.000
# loudness          113549.0      -8.243408  ...      -5.0010        4.532
# mode              113549.0       0.637866  ...       1.0000        1.000
# speechiness       113549.0       0.084674  ...       0.0845        0.965
# acousticness      113549.0       0.314064  ...       0.5960        0.996
# instrumentalness  113549.0       0.155703  ...       0.0487        1.000
# liveness          113549.0       0.213613  ...       0.2730        1.000
# valence           113549.0       0.474205  ...       0.6830        0.995
# tempo             113549.0     122.175745  ...     140.0740      243.372
# time_signature    113549.0       3.904218  ...       4.0000        5.000
#
# [14 rows x 8 columns]

# %%
# Remover músicas com duração maior que 30 minutos (1.800.000 ms)
# Aceitamos músicas com até 30 minutos (como as longas do Pink Floyd ou Iron Maiden)
df = df[df['duration_ms'] <= 1800000]

# Remover músicas com tempo (BPM) inválido ou ausente
# Valores válidos são maiores que 0 BPM (música sem batida identificável é inválida)
df = df[df['tempo'] > 0]

# Remover músicas com time signature inválido
# Valores válidos são 3, 4, 5... (não existe compasso 0)
df = df[df['time_signature'] > 0]

# Remover músicas com loudness (volume médio) absurdamente baixo
# Valores normais variam entre -5 dB (alto) até -30 dB (baixo); usamos -40 dB como limite
df = df[df['loudness'] > -40]

# %%
#ver informações gerias do dataframe após as exclusões
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113329 entries, 0 to 113999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          113329 non-null  object
#  1   artists           113329 non-null  object
#  2   album_name        113329 non-null  object
#  3   track_name        113329 non-null  object
#  4   popularity        113329 non-null  int64
#  5   duration_ms       113329 non-null  int64
#  6   explicit          113329 non-null  bool
#  7   danceability      113329 non-null  float64
#  8   energy            113329 non-null  float64
#  9   key               113329 non-null  int64
#  10  loudness          113329 non-null  float64
#  11  mode              113329 non-null  int64
#  12  speechiness       113329 non-null  float64
#  13  acousticness      113329 non-null  float64
#  14  instrumentalness  113329 non-null  float64
#  15  liveness          113329 non-null  float64
#  16  valence           113329 non-null  float64
#  17  tempo             113329 non-null  float64
#  18  time_signature    113329 non-null  int64
#  19  track_genre       113329 non-null  object
# dtypes: bool(1), float64(9), int64(5), object(5)
# memory usage: 17.4+ MB

# %%
#estatísticas descritivas após as exclusões
df.describe().T
# Out:
#                      count           mean  ...          75%          max
# popularity        113329.0      33.322239  ...      50.0000      100.000
# duration_ms       113329.0  227304.142664  ...  261600.0000  1800000.000
# danceability      113329.0       0.567902  ...       0.6950        0.985
# energy            113329.0       0.642933  ...       0.8540        1.000
# key               113329.0       5.309594  ...       8.0000       11.000
# loudness          113329.0      -8.216370  ...      -4.9980        4.532
# mode              113329.0       0.637851  ...       1.0000        1.000
# speechiness       113329.0       0.084796  ...       0.0847        0.965
# acousticness      113329.0       0.313678  ...       0.5950        0.996
# instrumentalness  113329.0       0.154814  ...       0.0470        1.000
# liveness          113329.0       0.213318  ...       0.2730        1.000
# valence           113329.0       0.474947  ...       0.6830        0.995
# tempo             113329.0     122.344827  ...     140.0800      243.372
# time_signature    113329.0       3.909891  ...       4.0000        5.000
#
# [14 rows x 8 columns]

# %%
#Criando coluna binária de popularidade com um corte de popularidade 50. Pelas estatísticas descritivas, 50 é o valor que divide o 4ªquartil do 3ºquartil. Isso tornará a base de dados um pouco desbalanceada, mas retrata melhor a realidade, onde temos muito mais músicas com popularidades médias ou baixas do que Hits de sucesso. Para lidar bem com esse desbalanceamento na base de dados pretendo utilizar modelos de classificação como florestas aleatórias ou XGBoost que lidam bem com dados debalanceados.


import numpy as np

# Definir o corte em 50 para considerar 'popular'
corte_popularidade = 50

# Criar coluna binária: 1 = popular (>=50), 0 = não popular (<50)
df['popular_binaria'] = np.where(df['popularity'] >= corte_popularidade, 1, 0)

# Visualizar contagem
df['popular_binaria'].value_counts(normalize=True)
# Out:
# 0    0.741284
# 1    0.258716
# Name: popular_binaria, dtype: float64

# %%
#Remoção de colunas que não serão utilizadas no modelo

# Lista inicial de colunas para remover
colunas_remover = ['track_id', 'track_name', 'album_name', 'popularity']

# Remover colunas
df_modelo = df.drop(columns=colunas_remover)

# Conferir dimensões após exclusão
print(f'Dataset após remoção: {df_modelo.shape}')
df_modelo.head()
# Out:
# Dataset após remoção: (113329, 17)
#                   artists  duration_ms  ...  track_genre  popular_binaria
# 0             Gen Hoshino       230666  ...     acoustic                1
# 1            Ben Woodward       149610  ...     acoustic                1
# 2  Ingrid Michaelson;ZAYN       210826  ...     acoustic                1
# 3            Kina Grannis       201933  ...     acoustic                1
# 4        Chord Overstreet       198853  ...     acoustic                1
#
# [5 rows x 17 columns]

# %%
#Essa etapa calcula a média de popularidade por artista e seleciona os 5000 artistas mais populares. Em seguida, cria uma coluna binária que indica se um artista é relevante ou não se a música tiver participação de um desses 5000 artistas. Depois removo a coluna inicial artists.

# Passo 1: separar os artistas
df['artists_list'] = df['artists'].str.split(';')

# Explodir linhas para calcular média de popularidade por artista
df_explodido = df.explode('artists_list')

# Calcular média de popularidade por artista
media_artistas = (
    df_explodido.groupby('artists_list')['popularity']
    .mean()
    .sort_values(ascending=False)
)

# Selecionar top 5000 artistas mais populares
top_5000_artistas = set(media_artistas.head(5000).index)

# Passo 2: definir função para criar coluna binária
def marcar_artista_relevante(lista_artistas):
    if any(artista.strip() in top_5000_artistas for artista in lista_artistas):
        return 1
    else:
        return 0

# Passo 3: criar coluna binária
df_modelo['artistas_relevantes'] = df['artists_list'].apply(marcar_artista_relevante)

# Remover coluna original 'artists' e 'artists_list'
df_modelo = df_modelo.drop(columns=['artists'])

# Conferir resultado
df_modelo['artistas_relevantes'].value_counts(normalize=True)
# Out:
# 0    0.840782
# 1    0.159218
# Name: artistas_relevantes, dtype: float64

# %%
# OneHotEncoding para track_genre
df_modelo = pd.get_dummies(df_modelo, columns=['track_genre'], drop_first=True)

print(f'Dataset após OneHotEncoding: {df_modelo.shape}')
df_modelo.head()
# Out:
# Dataset após OneHotEncoding: (113329, 129)
#    duration_ms  explicit  ...  track_genre_turkish  track_genre_world-music
# 0       230666     False  ...                    0                        0
# 1       149610     False  ...                    0                        0
# 2       210826     False  ...                    0                        0
# 3       201933     False  ...                    0                        0
# 4       198853     False  ...                    0                        0
#
# [5 rows x 129 columns]

# %%
# %pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Obtaining dependency information for imbalanced-learn from https://files.pythonhosted.org/packages/9d/41/721fec82606242a2072ee909086ff918dfad7d0199a9dfd4928df9c72494/imbalanced_learn-0.13.0-py3-none-any.whl.metadata
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting numpy<3,>=1.24.3 (from imbalanced-learn)
#   Obtaining dependency information for numpy<3,>=1.24.3 from https://files.pythonhosted.org/packages/75/c9/9bec03675192077467a9c7c2bdd1f2e922bd01d3a69b15c3a0fdcd8548f6/numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata
#   Downloading numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/62.1 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2,>=1.10.1 in /databricks/python3/lib/python3.11/site-packages (from imbalanced-learn) (1.11.1)
# Collecting scikit-learn<2,>=1.3.2 (from imbalanced-learn)
#   Obtaining dependency information for scikit-learn<2,>=1.3.2 from https://files.pythonhosted.org/packages/26/92/85ec172418f39474c1cd0221d611345d4f433fc4ee2fc68e01f524ccc4e4/scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn)
#   Obtaining dependency information for sklearn-compat<1,>=0.1 from https://files.pythonhosted.org/packages/f0/a8/ad69cf130fbd017660cdd64abbef3f28135d9e2e15fe3002e03c5be0ca38/sklearn_compat-0.1.3-py3-none-any.whl.metadata
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: joblib<2,>=1.1.1 in /databricks/python3/lib/python3.11/site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from imbalanced-learn) (3.1.0)
# Collecting numpy<3,>=1.24.3 (from imbalanced-learn)
#   Obtaining dependency information for numpy<3,>=1.24.3 from https://files.pythonhosted.org/packages/3a/d0/edc009c27b406c4f9cbc79274d6e46d634d139075492ad055e3d68445925/numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/61.0 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.1 MB/s eta 0:00:00
# Collecting scikit-learn<2,>=1.3.2 (from imbalanced-learn)
#   Obtaining dependency information for scikit-learn<2,>=1.3.2 from https://files.pythonhosted.org/packages/a8/f3/62fc9a5a659bb58a03cdd7e258956a5824bdc9b4bb3c5d932f55880be569/scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/238.4 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 14.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/18.3 MB ? eta -:--:--
#    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.8/18.3 MB 847.4 kB/s eta 0:00:21
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/18.3 MB 4.8 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━ 8.6/18.3 MB 8.3 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 12.3/18.3 MB 108.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━ 16.8/18.3 MB 114.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 116.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 11.3 MB/s eta 0:00:00
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/13.5 MB ? eta -:--:--
#    ━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/13.5 MB 92.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━ 6.4/13.5 MB 93.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 9.5/13.5 MB 91.7 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 13.5/13.5 MB 103.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: numpy, scikit-learn, sklearn-compat, imbalanced-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Not uninstalling numpy at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6
#     Can't uninstall 'numpy'. No files were found to uninstall.
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Not uninstalling scikit-learn at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
# Successfully installed imbalanced-learn-0.13.0 numpy-1.26.4 scikit-learn-1.6.1 sklearn-compat-0.1.3
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
#Modelo de Florestas Aleatórias - Apliquei o RandomOverSample para fazer uma reamostragem dos dados para melhor balanceá-los e depois utilzei esse modelo com a divisão de dados com validação cruzada 

# Imports necessários
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from imblearn.over_sampling import RandomOverSampler
import numpy as np

# Separando treino e teste (20% para teste)
X = df_modelo.drop(columns=['popular_binaria'])
y = df_modelo['popular_binaria']

X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

print(f"Tamanho treino: {X_treino.shape}, Tamanho teste: {X_teste.shape}")
print(f"Distribuição treino:\n{y_treino.value_counts(normalize=True)}")
print(f"Distribuição teste:\n{y_teste.value_counts(normalize=True)}")

# Aplicando RandomOverSampler no conjunto de treino
ros = RandomOverSampler(random_state=42)
X_treino_res, y_treino_res = ros.fit_resample(X_treino, y_treino)

print(f"\nApós RandomOverSampler - Treino balanceado:")
print(y_treino_res.value_counts(normalize=True))

# Definindo StratifiedKFold para validação cruzada balanceada
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Treinando RandomForest com validação cruzada usando dados balanceados
accuracies, precisions, recalls, f1_scores = [], [], [], []

for fold, (train_idx, val_idx) in enumerate(skf.split(X_treino_res, y_treino_res)):
    X_fold_train, X_fold_val = X_treino_res.iloc[train_idx], X_treino_res.iloc[val_idx]
    y_fold_train, y_fold_val = y_treino_res.iloc[train_idx], y_treino_res.iloc[val_idx]
    
    model = RandomForestClassifier(random_state=42, n_jobs=-1)
    model.fit(X_fold_train, y_fold_train)
    y_pred = model.predict(X_fold_val)

    acc = accuracy_score(y_fold_val, y_pred)
    prec = precision_score(y_fold_val, y_pred)
    rec = recall_score(y_fold_val, y_pred)
    f1 = f1_score(y_fold_val, y_pred)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)

    print(f"\nFold {fold+1}")
    print(f"Acurácia: {acc:.4f}, Precisão: {prec:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

print("\n✅ Resultados Médios após Oversampling com RandomForest:")
print(f"Acurácia média: {np.mean(accuracies):.4f}")
print(f"Precisão média: {np.mean(precisions):.4f}")
print(f"Recall médio: {np.mean(recalls):.4f}")
print(f"F1-score médio: {np.mean(f1_scores):.4f}")
# Out:
# Tamanho treino: (90663, 128), Tamanho teste: (22666, 128)
# Distribuição treino:
# 0    0.741284
# 1    0.258716
# Name: popular_binaria, dtype: float64
# Distribuição teste:
# 0    0.741287
# 1    0.258713
# Name: popular_binaria, dtype: float64
#
# Após RandomOverSampler - Treino balanceado:
# 1    0.5
# 0    0.5
# Name: popular_binaria, dtype: float64
#
# Fold 1
# Acurácia: 0.9548, Precisão: 0.9496, Recall: 0.9606, F1: 0.9551
#
# Fold 2
# Acurácia: 0.9563, Precisão: 0.9499, Recall: 0.9634, F1: 0.9566
#
# Fold 3
# Acurácia: 0.9564, Precisão: 0.9514, Recall: 0.9619, F1: 0.9566
#
# Fold 4
# Acurácia: 0.9561, Precisão: 0.9511, Recall: 0.9616, F1: 0.9563
#
# Fold 5
# Acurácia: 0.9571, Precisão: 0.9491, Recall: 0.9659, F1: 0.9574
#
# ✅ Resultados Médios após Oversampling com RandomForest:
# Acurácia média: 0.9561
# Precisão média: 0.9502
# Recall médio: 0.9627
# F1-score médio: 0.9564

# %%
#Modelo de Florestas Aleatórias - Apliquei o RandomUnderSample para fazer uma reamostragem dos dados para melhor balanceá-los e depois utilzei esse modelo com a divisão de dados com validação cruzada 

from imblearn.under_sampling import RandomUnderSampler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Balanceamento com Undersampling
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X_treino, y_treino)

print(f"\nApós RandomUnderSampler - Treino balanceado:\n{y_res.value_counts(normalize=True)}")

# Modelo RandomForest
rf_clf = RandomForestClassifier(random_state=42, n_jobs=-1)

accuracies, precisions, recalls, f1_scores = [], [], [], []

for fold, (train_idx, val_idx) in enumerate(skf.split(X_res, y_res)):
    X_train, X_val = X_res.iloc[train_idx], X_res.iloc[val_idx]
    y_train, y_val = y_res.iloc[train_idx], y_res.iloc[val_idx]

    rf_clf.fit(X_train, y_train)
    y_pred = rf_clf.predict(X_val)

    acc = accuracy_score(y_val, y_pred)
    prec = precision_score(y_val, y_pred)
    rec = recall_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)

    print(f"\nFold {fold+1}")
    print(f"Acurácia: {acc:.4f}, Precisão: {prec:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

print("\n✅ Resultados Médios após Undersampling com RandomForest:")
print(f"Acurácia média: {np.mean(accuracies):.4f}")
print(f"Precisão média: {np.mean(precisions):.4f}")
print(f"Recall médio: {np.mean(recalls):.4f}")
print(f"F1-score médio: {np.mean(f1_scores):.4f}")
# Out:
# Após RandomUnderSampler - Treino balanceado:
# 0    0.5
# 1    0.5
# Name: popular_binaria, dtype: float64
#
# Fold 1
# Acurácia: 0.8457, Precisão: 0.9013, Recall: 0.7764, F1: 0.8342
#
# Fold 2
# Acurácia: 0.8412, Precisão: 0.8959, Recall: 0.7722, F1: 0.8294
#
# Fold 3
# Acurácia: 0.8430, Precisão: 0.8944, Recall: 0.7779, F1: 0.8321
#
# Fold 4
# Acurácia: 0.8355, Precisão: 0.8877, Recall: 0.7683, F1: 0.8237
#
# Fold 5
# Acurácia: 0.8349, Precisão: 0.8896, Recall: 0.7647, F1: 0.8224
#
# ✅ Resultados Médios após Undersampling com RandomForest:
# Acurácia média: 0.8401
# Precisão média: 0.8938
# Recall médio: 0.7719
# F1-score médio: 0.8284

# %%
#Modelo de Florestas Aleatórias - Aqui apliquei a validação cruzada antes do Smote, porque o Smote cria dados sintéticos, dessa forma utilizei ele dentro de cada fold para que ele não crie dados sintéticos que vazam informação para o conjunto de validação

from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Instanciando o SMOTE
smote = SMOTE(random_state=42)

# Listas para armazenar os resultados
accuracies, precisions, recalls, f1_scores = [], [], [], []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # Aplicando SMOTE no conjunto de treino
    X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
    print(f"\nApós SMOTE - Treino balanceado:\n{y_train_res.value_counts(normalize=True)}")
    
    # Treinando o modelo RandomForest
    rf = RandomForestClassifier(random_state=42, n_jobs=-1)
    rf.fit(X_train_res, y_train_res)
    y_pred = rf.predict(X_val)
    
    # Calculando métricas
    acc = accuracy_score(y_val, y_pred)
    prec = precision_score(y_val, y_pred)
    rec = recall_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)

    print(f"Fold {fold + 1}")
    print(f"Acurácia: {acc:.4f}, Precisão: {prec:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

print("\n✅ Resultados Médios após SMOTE com RandomForest:")
print(f"Acurácia média: {np.mean(accuracies):.4f}")
print(f"Precisão média: {np.mean(precisions):.4f}")
print(f"Recall médio: {np.mean(recalls):.4f}")
print(f"F1-score médio: {np.mean(f1_scores):.4f}")
# Out:
# Após SMOTE - Treino balanceado:
# 1    0.5
# 0    0.5
# Name: popular_binaria, dtype: float64
# Fold 1
# Acurácia: 0.8868, Precisão: 0.8022, Recall: 0.7464, F1: 0.7733
#
# Após SMOTE - Treino balanceado:
# 1    0.5
# 0    0.5
# Name: popular_binaria, dtype: float64
# Fold 2
# Acurácia: 0.8841, Precisão: 0.7938, Recall: 0.7457, F1: 0.7690
#
# Após SMOTE - Treino balanceado:
# 1    0.5
# 0    0.5
# Name: popular_binaria, dtype: float64
# Fold 3
# Acurácia: 0.8843, Precisão: 0.7952, Recall: 0.7447, F1: 0.7691
#
# Após SMOTE - Treino balanceado:
# 1    0.5
# 0    0.5
# Name: popular_binaria, dtype: float64
# Fold 4
# Acurácia: 0.8869, Precisão: 0.7989, Recall: 0.7522, F1: 0.7749
#
# Após SMOTE - Treino balanceado:
# 1    0.5
# 0    0.5
# Name: popular_binaria, dtype: float64
# Fold 5
# Acurácia: 0.8879, Precisão: 0.8057, Recall: 0.7468, F1: 0.7751
#
# ✅ Resultados Médios após SMOTE com RandomForest:
# Acurácia média: 0.8860
# Precisão média: 0.7992
# Recall médio: 0.7472
# F1-score médio: 0.7723

# %%
#Ajuste de Hiperparâmetros - Utilizei o modelo de floresta aleatória+RandomOverSample e o RandomizedSearchCV para realizar o ajuste de hiperparâmetros

from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler
import numpy as np

# Separando X e y
X = df_modelo.drop(columns=['popular_binaria'])
y = df_modelo['popular_binaria']

# Pipeline com reamostragem
pipeline = Pipeline(steps=[
    ('oversample', RandomOverSampler(random_state=42)),
    ('rf', RandomForestClassifier(random_state=42, n_jobs=-1))
])

# Hiperparâmetros com mais opções
param_distributions = {
    'rf__n_estimators': [10, 20, 50],
    'rf__max_depth': [None, 20, 30],
    'rf__min_samples_split': [2, 5, 10]
}

# Validação cruzada
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

random_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_distributions,
    n_iter=15,  # maior diversidade
    cv=skf,
    scoring='f1',
    verbose=2,
    n_jobs=1,  # usar todos os cores disponíveis
    random_state=42
)

random_search.fit(X, y)

print("\nMelhores hiperparâmetros:", random_search.best_params_)
print("Melhor f1-score médio:", random_search.best_score_)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# [CV] END rf__max_depth=None, rf__min_samples_split=10, rf__n_estimators=50; total time= 1.4min
# [CV] END rf__max_depth=None, rf__min_samples_split=10, rf__n_estimators=50; total time= 1.3min
# [CV] END rf__max_depth=None, rf__min_samples_split=10, rf__n_estimators=50; total time=  39.9s
# [CV] END rf__max_depth=20, rf__min_samples_split=5, rf__n_estimators=20; total time=  31.4s
# [CV] END rf__max_depth=20, rf__min_samples_split=5, rf__n_estimators=20; total time=   6.2s
# [CV] END rf__max_depth=20, rf__min_samples_split=5, rf__n_estimators=20; total time=  13.1s
# [CV] END rf__max_depth=20, rf__min_samples_split=2, rf__n_estimators=10; total time=   4.0s
# [CV] END rf__max_depth=20, rf__min_samples_split=2, rf__n_estimators=10; total time=   6.5s
# [CV] END rf__max_depth=20, rf__min_samples_split=2, rf__n_estimators=10; total time=  30.2s
# [CV] END rf__max_depth=30, rf__min_samples_split=5, rf__n_estimators=10; total time= 1.2min
# [CV] END rf__max_depth=30, rf__min_samples_split=5, rf__n_estimators=10; total time=  39.1s
# [CV] END rf__max_depth=30, rf__min_samples_split=5, rf__n_estimators=10; total time=  34.8s
# [CV] END rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=10; total time=  36.0s
# [CV] END rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=10; total time=  13.9s
# [CV] END rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=10; total time=   4.8s
# [CV] END rf__max_depth=20, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.8s
# [CV] END rf__max_depth=20, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.5s
# [CV] END rf__max_depth=20, rf__min_samples_split=2, rf__n_estimators=50; total time=   6.5s
# [CV] END rf__max_depth=20, rf__min_samples_split=10, rf__n_estimators=20; total time=   3.3s
# [CV] END rf__max_depth=20, rf__min_samples_split=10, rf__n_estimators=20; total time=   3.3s
# [CV] END rf__max_depth=20, rf__min_samples_split=10, rf__n_estimators=20; total time=   3.3s
# [CV] END rf__max_depth=20, rf__min_samples_split=10, rf__n_estimators=50; total time=   5.6s
# [CV] END rf__max_depth=20, rf__min_samples_split=10, rf__n_estimators=50; total time=   6.9s
# [CV] END rf__max_depth=20, rf__min_samples_split=10, rf__n_estimators=50; total time=   7.0s
# [CV] END rf__max_depth=20, rf__min_samples_split=5, rf__n_estimators=10; total time=   2.7s
# [CV] END rf__max_depth=20, rf__min_samples_split=5, rf__n_estimators=10; total time=   2.7s
# [CV] END rf__max_depth=20, rf__min_samples_split=5, rf__n_estimators=10; total time=   2.7s
# [CV] END rf__max_depth=30, rf__min_samples_split=10, rf__n_estimators=10; total time=   3.6s
# [CV] END rf__max_depth=30, rf__min_samples_split=10, rf__n_estimators=10; total time=   3.2s
# [CV] END rf__max_depth=30, rf__min_samples_split=10, rf__n_estimators=10; total time=   5.9s
# [CV] END rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=20; total time=   6.1s
# [CV] END rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=20; total time=   5.5s
# [CV] END rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=20; total time=   7.1s
# [CV] END rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=20; total time=   5.0s
# [CV] END rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=20; total time=  13.6s
# [CV] END rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=20; total time=   5.3s
# [CV] END rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50; total time=  10.1s
# [CV] END rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50; total time=  46.1s
# [CV] END rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50; total time=  16.3s
# [CV] END rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50; total time=  17.1s
# [CV] END rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50; total time=  32.6s
# [CV] END rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50; total time=  25.1s
# [CV] END rf__max_depth=20, rf__min_samples_split=10, rf__n_estimators=10; total time=   2.6s
# [CV] END rf__max_depth=20, rf__min_samples_split=10, rf__n_estimators=10; total time=   2.7s
# [CV] END rf__max_depth=20, rf__min_samples_split=10, rf__n_estimators=10; total time=   4.6s
#
# Melhores hiperparâmetros: {'rf__n_estimators': 50, 'rf__min_samples_split': 2, 'rf__max_depth': None}
# Melhor f1-score médio: 0.7666749600806563

# %%
# %pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/cc/f5/1b5d88e5a65168b435e8339b53d027e3e7adecb0c7d157bc86d18f78471b/xgboost-3.0.2-py3-none-manylinux_2_28_x86_64.whl.metadata
#   Downloading xgboost-3.0.2-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages (from xgboost) (1.26.4)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Obtaining dependency information for nvidia-nccl-cu12 from https://files.pythonhosted.org/packages/af/a0/271bd709800f946e92128d9927ab7462559858a25b48f285a617d447bd48/nvidia_nccl_cu12-2.27.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Downloading nvidia_nccl_cu12-2.27.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: scipy in /databricks/python3/lib/python3.11/site-packages (from xgboost) (1.11.1)
# Downloading xgboost-3.0.2-py3-none-manylinux_2_28_x86_64.whl (253.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/253.9 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/253.9 MB 13.0 MB/s eta 0:00:20
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/253.9 MB 36.6 MB/s eta 0:00:07
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/253.9 MB 5.1 MB/s eta 0:00:50
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/253.9 MB 8.6 MB/s eta 0:00:29
#    ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/253.9 MB 124.2 MB/s eta 0:00:02
#    ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/253.9 MB 108.6 MB/s eta 0:00:03
#    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/253.9 MB 12.9 MB/s eta 0:00:19
#    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/253.9 MB 12.8 MB/s eta 0:00:19
#    ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.8/253.9 MB 12.7 MB/s eta 0:00:19
#    ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.1/253.9 MB 111.3 MB/s eta 0:00:03
#    ━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.5/253.9 MB 122.1 MB/s eta 0:00:02
#    ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/253.9 MB 125.7 MB/s eta 0:00:02
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/253.9 MB 130.4 MB/s eta 0:00:02
#    ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/253.9 MB 124.4 MB/s eta 0:00:02
#    ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/253.9 MB 118.8 MB/s eta 0:00:02
#    ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/253.9 MB 118.8 MB/s eta 0:00:02
#    ━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/253.9 MB 121.1 MB/s eta 0:00:02
#    ━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/253.9 MB 116.8 MB/s eta 0:00:02
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/253.9 MB 112.7 MB/s eta 0:00:02
#    ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/253.9 MB 111.1 MB/s eta 0:00:02
#    ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.0/253.9 MB 109.4 MB/s eta 0:00:02
#    ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.8/253.9 MB 109.7 MB/s eta 0:00:02
#    ━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/253.9 MB 106.7 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/253.9 MB 102.8 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/253.9 MB 105.6 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/253.9 MB 100.5 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/253.9 MB 103.7 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━ 99.3/253.9 MB 107.5 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━ 104.1/253.9 MB 131.6 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━ 108.7/253.9 MB 132.0 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━ 113.2/253.9 MB 128.7 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━ 116.4/253.9 MB 115.3 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━ 119.8/253.9 MB 102.9 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 124.3/253.9 MB 102.7 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━ 128.8/253.9 MB 122.4 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 132.9/253.9 MB 121.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━ 137.6/253.9 MB 15.7 MB/s eta 0:00:08
#    ━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━ 142.3/253.9 MB 15.8 MB/s eta 0:00:08
#    ━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 146.9/253.9 MB 132.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━ 151.6/253.9 MB 132.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 156.3/253.9 MB 133.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━ 161.1/253.9 MB 133.7 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━ 164.4/253.9 MB 117.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━ 166.4/253.9 MB 98.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━ 167.4/253.9 MB 76.3 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 168.9/253.9 MB 65.8 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 169.9/253.9 MB 56.2 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 170.9/253.9 MB 49.3 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━ 172.1/253.9 MB 44.8 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━ 173.2/253.9 MB 39.1 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━ 174.6/253.9 MB 36.4 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━ 175.5/253.9 MB 33.1 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━ 176.8/253.9 MB 33.5 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 178.0/253.9 MB 33.3 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 178.7/253.9 MB 32.8 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 180.2/253.9 MB 33.0 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━ 181.2/253.9 MB 31.6 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━ 182.3/253.9 MB 31.4 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━ 183.3/253.9 MB 32.1 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━ 184.2/253.9 MB 31.5 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━ 185.6/253.9 MB 30.8 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━ 186.7/253.9 MB 31.4 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 187.4/253.9 MB 30.5 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 188.9/253.9 MB 30.5 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 189.9/253.9 MB 30.5 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 191.0/253.9 MB 31.0 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━ 195.5/253.9 MB 15.9 MB/s eta 0:00:04
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 199.9/253.9 MB 19.2 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 203.0/253.9 MB 111.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 206.4/253.9 MB 116.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 208.4/253.9 MB 99.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 208.4/253.9 MB 99.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 208.4/253.9 MB 99.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━ 211.6/253.9 MB 51.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━ 213.4/253.9 MB 50.7 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━ 214.7/253.9 MB 43.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 215.8/253.9 MB 40.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 217.1/253.9 MB 36.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 218.4/253.9 MB 35.2 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 219.6/253.9 MB 45.7 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 220.7/253.9 MB 39.7 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 221.6/253.9 MB 36.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 222.8/253.9 MB 33.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 223.5/253.9 MB 31.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 224.5/253.9 MB 32.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 225.6/253.9 MB 30.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 226.5/253.9 MB 30.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 227.6/253.9 MB 29.3 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 228.3/253.9 MB 28.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 229.4/253.9 MB 27.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 230.0/253.9 MB 28.3 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 231.1/253.9 MB 27.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━ 232.1/253.9 MB 27.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━ 233.3/253.9 MB 27.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━ 234.0/253.9 MB 27.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━ 235.0/253.9 MB 4.4 MB/s eta 0:00:05
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 238.6/253.9 MB 4.6 MB/s eta 0:00:04
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 239.8/253.9 MB 4.6 MB/s eta 0:00:04
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━ 241.6/253.9 MB 4.7 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━ 243.4/253.9 MB 4.7 MB/s eta 0:00:03
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━ 246.8/253.9 MB 61.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 248.3/253.9 MB 53.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 250.2/253.9 MB 58.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 251.1/253.9 MB 54.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.4/253.9 MB 57.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 253.9/253.9 MB 55.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# 322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 322.5/322.5 MB 12.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 MB 90.2 kB/s eta 0:00:00
# Installing collected packages: nvidia-nccl-cu12, xgboost
# Successfully installed nvidia-nccl-cu12-2.27.6 xgboost-3.0.2
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
#Ajuste de Hiperparâmetros - Utilizei o modelo XGBoost+RandomOverSample e o RandomizedSearchCV para realizar o ajuste de hiperparâmetros

from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler
from xgboost import XGBClassifier
import numpy as np

# Separando X e y
X = df_modelo.drop(columns=['popular_binaria'])
y = df_modelo['popular_binaria']

# Pipeline com reamostragem e XGBoost
pipeline = Pipeline(steps=[
    ('oversample', RandomOverSampler(random_state=42)),
    ('xgb', XGBClassifier(random_state=42, n_jobs=-1, use_label_encoder=False, eval_metric='logloss'))
])

# Definindo o grid de hiperparâmetros
param_distributions = {
    'xgb__n_estimators': [50, 100, 200],
    'xgb__max_depth': [3, 5, 7],
    'xgb__learning_rate': [0.01, 0.1, 0.2],
    'xgb__subsample': [0.7, 0.9, 1.0],
    'xgb__colsample_bytree': [0.7, 0.9, 1.0]
}

# Validação cruzada
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_distributions,
    n_iter=10,  # quantidade reduzida para teste inicial
    cv=skf,
    scoring='f1',
    verbose=2,
    n_jobs=-1,
    random_state=42
)

# Treinar o modelo
random_search.fit(X, y)

# Resultados
print("\nMelhores hiperparâmetros:", random_search.best_params_)
print("Melhor f1-score médio:", random_search.best_score_)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:41:56] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:41:56] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:41:56] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:41:56] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:04] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:05] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:06] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:06] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:13] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:14] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:20] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:21] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:22] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:22] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:25] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:27] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:28] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:29] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:32] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:33] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:37] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:37] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:42:41] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:43:03] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:43:05] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:43:05] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:43:05] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf361a04-a89c-452c-928c-6050d9f348b6/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [00:43:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Melhores hiperparâmetros: {'xgb__subsample': 0.7, 'xgb__n_estimators': 200, 'xgb__max_depth': 5, 'xgb__learning_rate': 0.2, 'xgb__colsample_bytree': 0.9}
# Melhor f1-score médio: 0.7106477229769652
